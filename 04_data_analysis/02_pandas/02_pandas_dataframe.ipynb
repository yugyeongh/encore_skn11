# %% [markdown]
# # pandas - DataFrame
# - 2차원 행렬(표), Series를 묶어낸 자료형

# %%
import numpy as np
import pandas as pd

# %%
# dictionary-list 활용
data = {
    'one': [1,2,3,4,5],
    'two': ['가','나','다','라','마'],
    'three': [1.23, 2.34, 3.45, 4.56, 5.67],
    'four': True
}

df = pd.DataFrame(data)
df
# Out:
#    one two  three  four
# 0    1   가   1.23  True
# 1    2   나   2.34  True
# 2    3   다   3.45  True
# 3    4   라   4.56  True
# 4    5   마   5.67  True

# %%
# list-dictionary 활용
data = [
    {'a':1,'b':2,'c':3},
    {'b':5,'c':6},
    {'a':7,'b':8,'c':9}
]

df = pd.DataFrame(data)
df.index = ['토끼','판다','코알라']
print(df.index)

df.columns = ['협동심','성실도','인내심']
print(df.columns)
df
# Out:
# Index(['토끼', '판다', '코알라'], dtype='object')
# Index(['협동심', '성실도', '인내심'], dtype='object')
#      협동심  성실도  인내심
# 토끼   1.0    2    3
# 판다   NaN    5    6
# 코알라  7.0    8    9

# %%
# 2차원 ndarray 활용
arr = np.random.randn(2,3)
df = pd.DataFrame(arr, index=['ㄱ','ㄴ'], columns=['A','B','C']) # df로 만드는 과정에서 바로 index와 columns를 설정
df
# Out:
#           A         B         C
# ㄱ -1.085395 -0.146031 -1.339903
# ㄴ -1.095149 -0.993352 -1.440397

# %%
data = {
    '이름':['토순','곰돌','멍냥'],
    '위치':['독산','종로','천호'],
    '성별':['F','F','M']
}

df = pd.DataFrame(data)
df
# Out:
#    이름  위치 성별
# 0  토순  독산  F
# 1  곰돌  종로  F
# 2  멍냥  천호  M

# %%
df.T
# Out:
#      0   1   2
# 이름  토순  곰돌  멍냥
# 위치  독산  종로  천호
# 성별   F   F   M

# %% [markdown]
# ### DataFrame 속성

# %%
print(df.index)
print(df.columns)
print(df.values)
# Out:
# RangeIndex(start=0, stop=3, step=1)
# Index(['이름', '위치', '성별'], dtype='object')
# [['토순' '독산' 'F']
#  ['곰돌' '종로' 'F']
#  ['멍냥' '천호' 'M']]

# %%
print(df.shape) # 형태
print(df.size) # 요소 개수
print(df.ndim) # 깊이
print(df.dtypes) # 요소의 자료형
# Out:
# (3, 3)
# 9
# 2
# 이름    object
# 위치    object
# 성별    object
# dtype: object

# %% [markdown]
# ---
# ### DataFrame 메서드

# %%
bank_client_df = pd.DataFrame({
    'Client ID': [1, 2, 3, 4],
    'Client Name': ['Aly', 'Steve', 'Nicole', 'Morris'],
    'Net worth [$]': [35000, 3000, 100000, 2000],
    'Years with bank': [4, 7, 10, 15]
})

bank_client_df
# Out:
#    Client ID Client Name  Net worth [$]  Years with bank
# 0          1         Aly          35000                4
# 1          2       Steve           3000                7
# 2          3      Nicole         100000               10
# 3          4      Morris           2000               15

# %%
print(bank_client_df.head(2))
print(bank_client_df.tail(2))
# Out:
#    Client ID Client Name  Net worth [$]  Years with bank
# 0          1         Aly          35000                4
# 1          2       Steve           3000                7
#    Client ID Client Name  Net worth [$]  Years with bank
# 2          3      Nicole         100000               10
# 3          4      Morris           2000               15

# %%
bank_client_df.info() # metadata
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Client ID        4 non-null      int64
#  1   Client Name      4 non-null      object
#  2   Net worth [$]    4 non-null      int64
#  3   Years with bank  4 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 260.0+ bytes

# %%
bank_client_df.describe() # 숫자형태만 나옴 object는 안나옴 -> 평균, 표준편차 등은 object는 못구하기 때문
# Out:
#        Client ID  Net worth [$]  Years with bank
# count   4.000000       4.000000         4.000000
# mean    2.500000   35000.000000         9.000000
# std     1.290994   45963.753836         4.690416
# min     1.000000    2000.000000         4.000000
# 25%     1.750000    2750.000000         6.250000
# 50%     2.500000   19000.000000         8.500000
# 75%     3.250000   51250.000000        11.250000
# max     4.000000  100000.000000        15.000000

# %%
# indexing/slicing
# iloc 인덱스 - 행/열 순서로 조회
# loc 라벨 - 행/열 순서로 조회
print(bank_client_df.iloc[0])
print(type(bank_client_df.iloc[0]))
print(bank_client_df.loc[0].index)
print(type(bank_client_df.loc[0].name))
# Out:
# Client ID              1
# Client Name          Aly
# Net worth [$]      35000
# Years with bank        4
# Name: 0, dtype: object
# <class 'pandas.core.series.Series'>
# Index(['Client ID', 'Client Name', 'Net worth [$]', 'Years with bank'], dtype='object')
# <class 'int'>

# %%
bank_client_df.iloc[:2], type(bank_client_df.iloc[:2])
# Out:
# (   Client ID Client Name  Net worth [$]  Years with bank
#  0          1         Aly          35000                4
#  1          2       Steve           3000                7,
#  pandas.core.frame.DataFrame)

# %%
bank_client_df.iloc[[0,2]], type(bank_client_df.iloc[[0,2]])
# Out:
# (   Client ID Client Name  Net worth [$]  Years with bank
#  0          1         Aly          35000                4
#  2          3      Nicole         100000               10,
#  pandas.core.frame.DataFrame)

# %%
# fancy indexing을 통한 조회는 결과가 1개여도 dataframe 타입으로 반환
# -> (인덱싱) Series를 반환한다는 것은 차원을 축소(제거)하는 ㅓㄳ
# -> DataFrame을 반환한다는 것은 차원을 유지하는 것
print(bank_client_df.iloc[[2]].shape)
print(bank_client_df.iloc[2].shape)
bank_client_df.iloc[[2]], type(bank_client_df.iloc[[2]])
# Out:
# (1, 4)
# (4,)
# (   Client ID Client Name  Net worth [$]  Years with bank
#  2          3      Nicole         100000               10,
#  pandas.core.frame.DataFrame)

# %%
# 2차원 indexing - 한 차원 낮아짐 /slicing - 차원 유지
# bank_client_df.iloc[0,1]
bank_client_df.iloc[:2,1], type(bank_client_df.iloc[:2,1])
# Out:
# (0      Aly
#  1    Steve
#  Name: Client Name, dtype: object,
#  pandas.core.series.Series)

# %%
bank_client_df
# Out:
#    Client ID Client Name  Net worth [$]  Years with bank
# 0          1         Aly          35000                4
# 1          2       Steve           3000                7
# 2          3      Nicole         100000               10
# 3          4      Morris           2000               15

# %%
bank_client_df.index =  ['client1','client2','client3','client4']
bank_client_df
# Out:
#          Client ID Client Name  Net worth [$]  Years with bank
# client1          1         Aly          35000                4
# client2          2       Steve           3000                7
# client3          3      Nicole         100000               10
# client4          4      Morris           2000               15

# %%
bank_client_df.loc['client3'] # loc: 라벨로 가져옴
# Out:
# Client ID               3
# Client Name        Nicole
# Net worth [$]      100000
# Years with bank        10
# Name: client3, dtype: object

# %%
bank_client_df.loc['client2':'client4':2] # 시작 idx : 끝 idx :offset
# Out:
#          Client ID Client Name  Net worth [$]  Years with bank
# client2          2       Steve           3000                7
# client4          4      Morris           2000               15

# %%
bank_client_df.loc['client2':'client4':2, 'Client Name'], type(bank_client_df.loc['client2':'client4':2, 'Client Name'])
# Out:
# (client2     Steve
#  client4    Morris
#  Name: Client Name, dtype: object,
#  pandas.core.series.Series)

# %%
bank_client_df.loc['client2':'client4':2, 'Client Name': 'Net worth [$]'], type(bank_client_df.loc['client2':'client4':2, 'Client Name': 'Net worth [$]'])
# Out:
# (        Client Name  Net worth [$]
#  client2       Steve           3000
#  client4      Morris           2000,
#  pandas.core.frame.DataFrame)

# %%
# 열에 해당하는 것 fancy indexing 주기
bank_client_df.loc['client2':'client4':2, ['Client Name','Years with bank']]
# Out:
#         Client Name  Years with bank
# client2       Steve                7
# client4      Morris               15

# %%
bank_client_df
# Out:
#          Client ID Client Name  Net worth [$]  Years with bank
# client1          1         Aly          35000                4
# client2          2       Steve           3000                7
# client3          3      Nicole         100000               10
# client4          4      Morris           2000               15

# %%
# 이름이 Steve인 고객 정보 출력 # loc와 iloc의 차이가 뭘까나..
bank_client_df.loc[bank_client_df['Client Name'] == 'Steve']
# Out:
#          Client ID Client Name  Net worth [$]  Years with bank
# client2          2       Steve           3000                7

# %%
# client name만 출력
bank_client_df['Client Name'] # series 형태로 client name만
# Out:
# client1       Aly
# client2     Steve
# client3    Nicole
# client4    Morris
# Name: Client Name, dtype: object

# %%
# client name과 net worth [$] 출력 -> fancy indexing으로 가져오기
bank_client_df[['Client Name','Net worth [$]']]
# Out:
#         Client Name  Net worth [$]
# client1         Aly          35000
# client2       Steve           3000
# client3      Nicole         100000
# client4      Morris           2000

# %%
# 바로 위의 fancy indexing과 같은 결과가 나옴
bank_client_df.filter(items =['Client Name','Net worth [$]'])
# Out:
#         Client Name  Net worth [$]
# client1         Aly          35000
# client2       Steve           3000
# client3      Nicole         100000
# client4      Morris           2000

# %%
bank_client_df.filter(like='$', axis=1) # 열을 가리킴
# Out:
#          Net worth [$]
# client1          35000
# client2           3000
# client3         100000
# client4           2000

# %%
bank_client_df.filter(like='4', axis=0)
# Out:
#          Client ID Client Name  Net worth [$]  Years with bank
# client4          4      Morris           2000               15

# %% [markdown]
# ---
# ### 행 추가 및 삭제

# %%
students = [
    {'name': '호랑이', 'midterm': 95, 'final': 85},
    {'name': '늑대', 'midterm': 93, 'final': 90},
    {'name': '양', 'midterm': 100, 'final': 10}
]

df = pd.DataFrame(students)
df
# Out:
#   name  midterm  final
# 0  호랑이       95     85
# 1   늑대       93     90
# 2    양      100     10

# %%
df.loc[len(df)] = ['하마',88,72]
df
# Out:
#   name  midterm  final
# 0  호랑이       95     85
# 1   늑대       93     90
# 2    양      100     10
# 3   하마       88     72

# %%
add_student_df = pd.DataFrame([['곰',99,24]], columns=['name','midterm','final']) # columns를 지정해야 함
df = pd.concat([df, add_student_df], ignore_index=True) # index가 이상하게 꼬이는걸 방지할 수 있음
df
# Out:
#   name  midterm  final
# 0  호랑이       95     85
# 1   늑대       93     90
# 2    양      100     10
# 3   하마       88     72
# 4    곰       99     24

# %%
# 행 삭제 - index 이용
df.drop(df.index[[0]], inplace=True) # inplace 속성을 넣어서 df에 저장하지 않아도 변화준 것이 그대로 반영됨
df
# Out:
#   name  midterm  final
# 2    양      100     10

# %% [markdown]
# ---
# ### 컬럼 추가

# %%
df = pd.DataFrame({
    '이름':['토순','곰돌','멍냥'],
    '위치':['독산','종로','천호'],
    '성별':['F','F','M']
})

# %%
# 컬럼명 이용
df['취미'] = ['인공지능 공부','NaN','NaN']
df
# Out:
#    이름  위치 성별       취미
# 0  토순  독산  F  인공지능 공부
# 1  곰돌  종로  F      NaN
# 2  멍냥  천호  M      NaN

# %%
# 컬럼명과 np.where(조건, True일 때 값, False일 때 값) => ndarray를 이용
df['성별(한글)'] = np.where(df['성별'] == 'M', '남성','여성')
df
# Out:
#    이름  위치 성별       취미 성별(한글)
# 0  토순  독산  F  인공지능 공부     여성
# 1  곰돌  종로  F      NaN     여성
# 2  멍냥  천호  M      NaN     남성

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    '이름':['토순','곰돌','멍냥'],
    '위치':['독산','종로','천호'],
    '성별':['F','F','M'],
    '키': [179,165,157],
    '체중': [50, 48.2, 51.3]
})

# %%
# 컬럼명과 기존 컬렴 연산 이용
df['BMI'] = df['체중'] /((df['키'] * 0.01)**2)  # bmi = kg/m^2
df
# Out:
#    이름  위치 성별    키    체중        BMI
# 0  토순  독산  F  179  50.0  15.605006
# 1  곰돌  종로  F  165  48.2  17.704316
# 2  멍냥  천호  M  157  51.3  20.812203

# %%
# apply: 콜백 함수를 받는다 (콜백 함수는 인자로 전달되는 함수수)
def get_type(value):
    return '저체중' if value < 18 else '표준'

df['BMI type'] = df['BMI'].apply(get_type) # 인자로 함수를 전달함
df
# Out:
#    이름  위치 성별    키    체중        BMI BMI type
# 0  토순  독산  F  179  50.0  15.605006      저체중
# 1  곰돌  종로  F  165  48.2  17.704316      저체중
# 2  멍냥  천호  M  157  51.3  20.812203       표준

# %%
# 컬럼 삭제: drop 이용
df.drop('BMI type', axis=1) # 열에 대한 삭제이기 떄문에 1넣기 / 드롭된 걸 반환해주는 함수기 때문에 df로 다시 받아야 함 or inplace=True
df.drop('BMI type', axis=1, inplace=True)
df
# Out:
#    이름  위치 성별    키    체중        BMI
# 0  토순  독산  F  179  50.0  15.605006
# 1  곰돌  종로  F  165  48.2  17.704316
# 2  멍냥  천호  M  157  51.3  20.812203

# %% [markdown]
# ---
# ### 정렬

# %%
df = pd.read_csv('../data/bank_client_information.csv')
df
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
#
#    Years with Bank
# 0                5
# 1                6
# 2                7
# 3               10
# 4               22
# 5               26
# 6               11
# 7                3
# 8                1
# 9               13

# %%
df.sort_values('Net Worth', ascending=False)
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
#
#    Years with Bank
# 5               26
# 6               11
# 7                3
# 3               10
# 1                6
# 2                7
# 9               13
# 0                5
# 4               22
# 8                1

# %%
# 오래된 고객순
df.sort_values('Years with Bank', ascending=False)
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
#
#    Years with Bank
# 5               26
# 4               22
# 9               13
# 6               11
# 3               10
# 2                7
# 1                6
# 0                5
# 7                3
# 8                1

# %%
# 순자산이 많고 오래된 고객순
# 정렬 기준으로 n개의 컬럼을 사용할 수 있으며, 이때 ascending 속성 역시 짝을 맞추어 n개를 전달해야 함
df.sort_values(['Net Worth', 'Years with Bank'], ascending=[False, False])
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
#
#    Years with Bank
# 5               26
# 6               11
# 7                3
# 3               10
# 1                6
# 2                7
# 9               13
# 4               22
# 0                5
# 8                1

# %%
# rank()
df['Rank'] = df['Net Worth'].rank(ascending=False).astype(int) # astype을 지우게 된다면 float(실수) 형태로 나타남
df.sort_values('Rank')
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
#
#    Years with Bank  Rank
# 5               26     1
# 6               11     2
# 7                3     3
# 3               10     4
# 1                6     5
# 2                7     6
# 9               13     7
# 0                5     8
# 4               22     8
# 8                1    10

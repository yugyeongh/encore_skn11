# %% [markdown]
# # XGBoost

# %% [markdown]
# https://xgboost.readthedocs.io/en/stable/index.html
#
# **핵심 파라미터**
# 1. **learning_rate**: 각 트리의 기여도를 조절하는 학습률로, 값이 작을수록 모델의 복잡도가 낮아지지만 더 많은 트리를 필요로 한다.
# 2. **n_estimators**: 트리의 개수를 의미하며, 많을수록 복잡한 모델이 된다.
# 3. **max_depth**: 각 트리의 최대 깊이로, 트리가 너무 깊으면 과적합될 수 있다.
# 4. **objective**: 손실 함수의 종류로, 회귀 문제의 경우 'reg:squarederror', 분류 문제의 경우 'binary:logistic' 등을 사용한다.

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-2.1.4-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\playdata\appdata\local\anaconda3\envs\pystudy_env\lib\site-packages (from xgboost) (2.2.3)
# Requirement already satisfied: scipy in c:\users\playdata\appdata\local\anaconda3\envs\pystudy_env\lib\site-packages (from xgboost) (1.15.2)
# Downloading xgboost-2.1.4-py3-none-win_amd64.whl (124.9 MB)
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    - -------------------------------------- 3.4/124.9 MB 16.7 MB/s eta 0:00:08
#    - -------------------------------------- 6.0/124.9 MB 15.4 MB/s eta 0:00:08
#    -- ------------------------------------- 8.7/124.9 MB 14.1 MB/s eta 0:00:09
#    --- ------------------------------------ 10.7/124.9 MB 13.7 MB/s eta 0:00:09
#    ---- ----------------------------------- 14.7/124.9 MB 14.2 MB/s eta 0:00:08
#    ----- ---------------------------------- 18.1/124.9 MB 14.6 MB/s eta 0:00:08
#    ------ --------------------------------- 21.0/124.9 MB 14.6 MB/s eta 0:00:08
#    ------- -------------------------------- 23.6/124.9 MB 14.2 MB/s eta 0:00:08
#    -------- ------------------------------- 26.5/124.9 MB 14.2 MB/s eta 0:00:07
#    --------- ------------------------------ 30.7/124.9 MB 14.9 MB/s eta 0:00:07
#    ---------- ----------------------------- 34.1/124.9 MB 15.0 MB/s eta 0:00:07
#    ----------- ---------------------------- 37.2/124.9 MB 15.1 MB/s eta 0:00:06
#    ------------- -------------------------- 41.7/124.9 MB 15.4 MB/s eta 0:00:06
#    -------------- ------------------------- 44.8/124.9 MB 15.4 MB/s eta 0:00:06
#    --------------- ------------------------ 48.8/124.9 MB 15.6 MB/s eta 0:00:05
#    ---------------- ----------------------- 52.7/124.9 MB 15.7 MB/s eta 0:00:05
#    ----------------- ---------------------- 54.5/124.9 MB 15.7 MB/s eta 0:00:05
#    ------------------ --------------------- 56.6/124.9 MB 15.0 MB/s eta 0:00:05
#    ------------------- -------------------- 60.6/124.9 MB 15.2 MB/s eta 0:00:05
#    -------------------- ------------------- 64.0/124.9 MB 15.4 MB/s eta 0:00:04
#    --------------------- ------------------ 67.9/124.9 MB 15.5 MB/s eta 0:00:04
#    ---------------------- ----------------- 70.5/124.9 MB 15.3 MB/s eta 0:00:04
#    ------------------------ --------------- 75.8/124.9 MB 15.7 MB/s eta 0:00:04
#    ------------------------- -------------- 81.0/124.9 MB 16.1 MB/s eta 0:00:03
#    --------------------------- ------------ 85.5/124.9 MB 16.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 87.6/124.9 MB 16.0 MB/s eta 0:00:03
#    ---------------------------- ----------- 90.4/124.9 MB 15.9 MB/s eta 0:00:03
#    ----------------------------- ---------- 93.3/124.9 MB 15.9 MB/s eta 0:00:02
#    ------------------------------- -------- 97.3/124.9 MB 16.0 MB/s eta 0:00:02
#    ------------------------------- ------- 102.2/124.9 MB 16.2 MB/s eta 0:00:02
#    --------------------------------- ----- 108.0/124.9 MB 16.5 MB/s eta 0:00:02
#    ----------------------------------- --- 112.7/124.9 MB 16.7 MB/s eta 0:00:01
#    ------------------------------------ -- 117.4/124.9 MB 16.9 MB/s eta 0:00:01
#    ------------------------------------- - 121.1/124.9 MB 16.9 MB/s eta 0:00:01
#    --------------------------------------  124.8/124.9 MB 16.9 MB/s eta 0:00:01
#    --------------------------------------- 124.9/124.9 MB 16.5 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-2.1.4

# %%
from xgboost import XGBClassifier   # xgboost에서는 sklearn과 비슷한 api 제공
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

iris_data = load_iris()
X_train, X_test, y_train, y_test = train_test_split(iris_data.data, iris_data.target, random_state=0)

xgb_clf = XGBClassifier(
    n_estimators=100,
    max_depth=3,
    learning_rate=0.1,
    random_state=0
)
xgb_clf.fit(X_train, y_train)

y_pred_train = xgb_clf.predict(X_train)
y_pred_test = xgb_clf.predict(X_test)

print(accuracy_score(y_train, y_pred_train))
print(accuracy_score(y_test, y_pred_test))
# Out:
# 1.0
# 0.9736842105263158

# %%
# 유방암 데이터셋 이진분류
from sklearn.datasets import load_breast_cancer

data = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, random_state=0)

xgb_clf = XGBClassifier(
    n_estimators=500,
    max_depth=3,
    learning_rate=0.1,
    random_state=0
    # early_stopping_rounds=10, # 성능이 일정 횟수 이상 향상되지 않으면 조기종료 (반복 )
    # eval_metrics='logloss'
)
xgb_clf.fit(X_train, y_train)

y_pred_train = xgb_clf.predict(X_train)
y_pred_test = xgb_clf.predict(X_test)

print(accuracy_score(y_train, y_pred_train))
print(accuracy_score(y_test, y_pred_test))
# Out:
# 1.0
# 0.9790209790209791

# %%
# XGBClassifier에 조기종료 적용 -> 과적합 방지, 훈련시간 단축
xgb_clf = XGBClassifier(
    n_estimators=500,
    max_depth=3,
    learning_rate=0.1,
    random_state=0,
    early_stopping_rounds=10, # 성능이 일정 횟수 이상 향상되지 않으면 조기종료 (반복을 중단)
    eval_metrics='logloss'
)

X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, random_state=0)
eval_set = [(X_tr, y_tr), (X_val, y_val)]
xgb_clf.fit(X_tr,y_tr, eval_set=eval_set, verbose=True)
# eval_set: 검증 데이터, verbose: 학습 중 평가 결과 출력 여부
# Out:
# [0]	validation_0-logloss:0.57481	validation_1-logloss:0.60855
# [1]	validation_0-logloss:0.50967	validation_1-logloss:0.55458
# [2]	validation_0-logloss:0.45738	validation_1-logloss:0.50524
# [3]	validation_0-logloss:0.40999	validation_1-logloss:0.46295
# [4]	validation_0-logloss:0.36974	validation_1-logloss:0.42707
# [5]	validation_0-logloss:0.33525	validation_1-logloss:0.39923
# [6]	validation_0-logloss:0.30479	validation_1-logloss:0.37175
# [7]	validation_0-logloss:0.27762	validation_1-logloss:0.34858
# [8]	validation_0-logloss:0.25423	validation_1-logloss:0.32846
# [9]	validation_0-logloss:0.23342	validation_1-logloss:0.30968
# [10]	validation_0-logloss:0.21391	validation_1-logloss:0.29418
# [11]	validation_0-logloss:0.19718	validation_1-logloss:0.28202
# [12]	validation_0-logloss:0.18261	validation_1-logloss:0.27007
# [13]	validation_0-logloss:0.16971	validation_1-logloss:0.25975
# [14]	validation_0-logloss:0.15828	validation_1-logloss:0.24955
# [15]	validation_0-logloss:0.14647	validation_1-logloss:0.24042
# [16]	validation_0-logloss:0.13670	validation_1-logloss:0.23337
# [17]	validation_0-logloss:0.12792	validation_1-logloss:0.22497
# [18]	validation_0-logloss:0.11898	validation_1-logloss:0.21875
# [19]	validation_0-logloss:0.11172	validation_1-logloss:0.21374
# [20]	validation_0-logloss:0.10511	validation_1-logloss:0.20948
# [21]	validation_0-logloss:0.09846	validation_1-logloss:0.20090
# [22]	validation_0-logloss:0.09255	validation_1-logloss:0.19452
# [23]	validation_0-logloss:0.08771	validation_1-logloss:0.18731
# [24]	validation_0-logloss:0.08283	validation_1-logloss:0.18402
# [25]	validation_0-logloss:0.07888	validation_1-logloss:0.17873
# [26]	validation_0-logloss:0.07464	validation_1-logloss:0.17608
# [27]	validation_0-logloss:0.07099	validation_1-logloss:0.17421
# [28]	validation_0-logloss:0.06785	validation_1-logloss:0.17230
# [29]	validation_0-logloss:0.06468	validation_1-logloss:0.17073
# [30]	validation_0-logloss:0.06190	validation_1-logloss:0.16732
# [31]	validation_0-logloss:0.05919	validation_1-logloss:0.16755
# [32]	validation_0-logloss:0.05678	validation_1-logloss:0.16742
# [33]	validation_0-logloss:0.05428	validation_1-logloss:0.16539
# [34]	validation_0-logloss:0.05197	validation_1-logloss:0.16359
# [35]	validation_0-logloss:0.04985	validation_1-logloss:0.16297
# [36]	validation_0-logloss:0.04780	validation_1-logloss:0.16166
# [37]	validation_0-logloss:0.04616	validation_1-logloss:0.16194
# [38]	validation_0-logloss:0.04415	validation_1-logloss:0.16041
# [39]	validation_0-logloss:0.04256	validation_1-logloss:0.16096
# [40]	validation_0-logloss:0.04088	validation_1-logloss:0.16050
# [41]	validation_0-logloss:0.03941	validation_1-logloss:0.15960
# [42]	validation_0-logloss:0.03801	validation_1-logloss:0.15769
# [43]	validation_0-logloss:0.03665	validation_1-logloss:0.15752
# [44]	validation_0-logloss:0.03526	validation_1-logloss:0.15663
# [45]	validation_0-logloss:0.03426	validation_1-logloss:0.15514
# [46]	validation_0-logloss:0.03311	validation_1-logloss:0.15276
# [47]	validation_0-logloss:0.03199	validation_1-logloss:0.15260
# [48]	validation_0-logloss:0.03100	validation_1-logloss:0.15057
# [49]	validation_0-logloss:0.03025	validation_1-logloss:0.15128
# [50]	validation_0-logloss:0.02934	validation_1-logloss:0.15097
# [51]	validation_0-logloss:0.02848	validation_1-logloss:0.15021
# [52]	validation_0-logloss:0.02775	validation_1-logloss:0.15079
# [53]	validation_0-logloss:0.02693	validation_1-logloss:0.15086
# [54]	validation_0-logloss:0.02606	validation_1-logloss:0.14912
# [55]	validation_0-logloss:0.02529	validation_1-logloss:0.14931
# [56]	validation_0-logloss:0.02469	validation_1-logloss:0.14727
# [57]	validation_0-logloss:0.02410	validation_1-logloss:0.14747
# [58]	validation_0-logloss:0.02335	validation_1-logloss:0.14895
# [59]	validation_0-logloss:0.02273	validation_1-logloss:0.14900
# [60]	validation_0-logloss:0.02232	validation_1-logloss:0.14822
# [61]	validation_0-logloss:0.02175	validation_1-logloss:0.14812
# [62]	validation_0-logloss:0.02115	validation_1-logloss:0.14960
# [63]	validation_0-logloss:0.02075	validation_1-logloss:0.14868
# [64]	validation_0-logloss:0.02016	validation_1-logloss:0.14652
# [65]	validation_0-logloss:0.01984	validation_1-logloss:0.14553
# [66]	validation_0-logloss:0.01952	validation_1-logloss:0.14491
# [67]	validation_0-logloss:0.01903	validation_1-logloss:0.14634
# [68]	validation_0-logloss:0.01870	validation_1-logloss:0.14556
# [69]	validation_0-logloss:0.01828	validation_1-logloss:0.14591
# [70]	validation_0-logloss:0.01803	validation_1-logloss:0.14482
# [71]	validation_0-logloss:0.01772	validation_1-logloss:0.14432
# [72]	validation_0-logloss:0.01738	validation_1-logloss:0.14312
# [73]	validation_0-logloss:0.01717	validation_1-logloss:0.14216
# [74]	validation_0-logloss:0.01693	validation_1-logloss:0.14175
# [75]	validation_0-logloss:0.01658	validation_1-logloss:0.14084
# [76]	validation_0-logloss:0.01624	validation_1-logloss:0.14119
# [77]	validation_0-logloss:0.01605	validation_1-logloss:0.14102
# [78]	validation_0-logloss:0.01583	validation_1-logloss:0.14056
# [79]	validation_0-logloss:0.01560	validation_1-logloss:0.13946
# [80]	validation_0-logloss:0.01542	validation_1-logloss:0.13962
# [81]	validation_0-logloss:0.01525	validation_1-logloss:0.13891
# [82]	validation_0-logloss:0.01507	validation_1-logloss:0.13819
# [83]	validation_0-logloss:0.01481	validation_1-logloss:0.13756
# [84]	validation_0-logloss:0.01465	validation_1-logloss:0.13672
# [85]	validation_0-logloss:0.01449	validation_1-logloss:0.13658
# [86]	validation_0-logloss:0.01425	validation_1-logloss:0.13568
# [87]	validation_0-logloss:0.01412	validation_1-logloss:0.13537
# [88]	validation_0-logloss:0.01391	validation_1-logloss:0.13486
# [89]	validation_0-logloss:0.01376	validation_1-logloss:0.13428
# [90]	validation_0-logloss:0.01361	validation_1-logloss:0.13464
# [91]	validation_0-logloss:0.01353	validation_1-logloss:0.13392
# [92]	validation_0-logloss:0.01339	validation_1-logloss:0.13383
# [93]	validation_0-logloss:0.01325	validation_1-logloss:0.13421
# [94]	validation_0-logloss:0.01314	validation_1-logloss:0.13390
# [95]	validation_0-logloss:0.01298	validation_1-logloss:0.13350
# [96]	validation_0-logloss:0.01291	validation_1-logloss:0.13342
# [97]	validation_0-logloss:0.01284	validation_1-logloss:0.13346
# [98]	validation_0-logloss:0.01274	validation_1-logloss:0.13317
# [99]	validation_0-logloss:0.01260	validation_1-logloss:0.13247
# [100]	validation_0-logloss:0.01247	validation_1-logloss:0.13284
# [101]	validation_0-logloss:0.01241	validation_1-logloss:0.13246
# [102]	validation_0-logloss:0.01226	validation_1-logloss:0.13290
# [103]	validation_0-logloss:0.01217	validation_1-logloss:0.13263
# [104]	validation_0-logloss:0.01206	validation_1-logloss:0.13259
# [105]	validation_0-logloss:0.01196	validation_1-logloss:0.13341
# [106]	validation_0-logloss:0.01190	validation_1-logloss:0.13335
# [107]	validation_0-logloss:0.01184	validation_1-logloss:0.13332
# [108]	validation_0-logloss:0.01176	validation_1-logloss:0.13308
# [109]	validation_0-logloss:0.01170	validation_1-logloss:0.13307
# [110]	validation_0-logloss:0.01165	validation_1-logloss:0.13272
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric=None,
#               eval_metrics='logloss', feature_types=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
# 훈련 과정 시각화
import matplotlib.pyplot as plt

result = xgb_clf.evals_result()
train_loss = result['validation_0']['logloss']
val_loss = result['validation_1']['logloss'] # validation이 손실이 더 높을수밖에 없음 학습 관련된 데이터라?

plt.plot(train_loss, label='train')
plt.plot(val_loss, label='validation')
plt.legend()
plt.xlabel('nth round')
plt.ylabel('logloss')
plt.show()

# %%
from xgboost import plot_importance

fig, ax = plt.subplots(figsize=(10,12))
plot_importance(xgb_clf, ax=ax)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>
